# %% [markdown]
# # **MAE598 Homework 2**

# %% [markdown]
# ### Q1. Show that the stationary point (zero gradient) of the function
# f ($x_{1}$, $x_{2}$) = 2$x_{1}^2$ - 4$x_{1}$$x_{2}$ +1.5$x_{2}^2$ + $x_{2}$
#
# ### is a saddle (with indefinite Hessian).
# ### Find the directions of downslopes away from the saddle. To do this, use Taylor’s expansion at the saddle point to show that
#
# f ($x_{1}$, $x_{2}$) = f(1, 1) + (a$∂x_{1}$ - b$∂x_{2}$)(c$∂x_{1}$ - d$∂x_{2}$),
#
# ###with some constants a, b, c, d and ∂$x_{i}$ = $x_{i}$ − 1 for i = 1, 2. Then the directions of downslopes are such (∂$x_{1}$, ∂$x_{2}$) that
#
# f ($x_{1}$, $x_{2}$)- f(1, 1) = (a$∂x_{1}$ - b$∂x_{2}$)(c$∂x_{1}$ - d$∂x_{2}$) < 0
#
# ###Answer -
#
# f = f ($x_{1}$, $x_{2}$) = 2$x_{1}^2$ - 4$x_{1}$$x_{2}$ +1.5$x_{2}^2$ + $x_{2}$
#
# \begin{align}
# g(f) = \begin{bmatrix}
# ∂f/∂x_{1} \\
# ∂f/∂x_{2}
# \end{bmatrix}
# \end{align}
#
# \begin{align}
# g(f) = \begin{bmatrix}
# 4x_{1}-4x_{2} \\
# -4x_{1}+3x_{2}+1
# \end{bmatrix}
# \end{align}
#
# ### For stationary point g(f)=0
# ###Therefore,
# \begin{align}
# \begin{bmatrix}
# 4x_{1}-4x_{2} \\
# -4x_{1}+3x_{2}+1
# \end{bmatrix} = \begin{bmatrix}
# 0 \\
# 0
# \end{bmatrix}
# \end{align}
#
# $4x_{1}-4x_{2}$ = 0
#
# $-4x_{1}+3x_{2} = -1$
#
# ### Using elimination method, we get $x_{1} = 1, x_{2}=1$
# ###Therefore the stationary point $(x_{1}, x_{2}) = (1,1)$
#
#
# \begin{align}
# H(f) = \begin{bmatrix}
# ∂^2f/∂x_{1}^2 & ∂^2f/∂x_{1}∂x_{2}\\
# ∂^2f/∂x_{2}∂x_{1} & ∂^2f/∂x_{2}^2
# \end{bmatrix} = \begin{bmatrix}
# 4 &-4 \\
# -4 & 3
# \end{bmatrix}
# \end{align}
#
#
# ### Eigen Value:
#
# AX = λX
#
# (A - λI)X = 0
#
# |A - λI|=0
#
# $λ_{1} = 7.53112 ; λ_{2} = -0.53112$
#
# ### Since the two eigen values of Hessian are positive and negativevalues, the fuction is indefinite. Therefore, the stationary point (1, 1) is a saddle point.
#
# ### Taylors function
# $f(x_{1}, x_{2}) = f(x_{1}, x_{2}) + |g(f)|^T (x-x_{0}) + 1/2(x-x_{0})^T H(f)(x-x_{0})$
#
# for $(x_{1}, x_{2}) = (1, 1)$
#
# $f(x_{1}, x_{2}) = f(1, 1) + \begin{bmatrix}4(1)-4(1) & -4(1)+3(1)+1\end{bmatrix}\begin{bmatrix}x_{1}-1 \\ x_{2}-1\end{bmatrix} + 1/2 \begin{bmatrix}x_{1}-1 & x_{2}-1\end{bmatrix}\begin{bmatrix}4 & -4 \\ -4 & 3\end{bmatrix}\begin{bmatrix}x_{1}-1 & x_{2}-1\end{bmatrix}$
#
# ### let $x_{1} -1 = ∂x_{1}, x_{2} - 1 = ∂x_{2}$
#
# $f(x_{1}, x_{2}) = f(1, 1) + 0 + 1/2 \begin{bmatrix}∂x_{1} & ∂x_{2}\end{bmatrix}\begin{bmatrix}4 & -4 \\ -4 & 3\end{bmatrix}\begin{bmatrix}∂x_{1} \\ ∂x_{2}\end{bmatrix}$
#
# $= f(1, 1) + 1/2 \begin{bmatrix}4∂x_{1}-4∂x_{2} & -4∂x_{1}+3∂x_{2}\end{bmatrix}\begin{bmatrix}∂x_{1} \\ ∂x_{2}\end{bmatrix}$
#
# $= f(1, 1) + 1/2 \begin{bmatrix}(4∂x_{1}^2-4∂x_{1}∂x_{2}-4∂x_{1}∂x_{2}+3∂x_{2}^2)\end{bmatrix}$
#
# $= f(1, 1) + 1/2 \begin{bmatrix}(2∂x_{1}-∂x_{2})(2∂x_{1}-3∂x_{2})\end{bmatrix}$
#
# $= f(1, 1) + \begin{bmatrix}(1∂x_{1}-1/2∂x_{2})(1∂x_{1}-3/2∂x_{2})\end{bmatrix}$
#
# ###let a = 1, b = 1/2, c = 1, d = 3/2
#
# ###Therefore,
#
# $f(x_{1}, x_{2}) = f(1, 1) + (a∂x_{1}-b∂x_{2})(c∂x_{1}-d∂x_{2})$
#
# ###Directions of downslopes,
#
# $f(x_{1}, x_{2})-f(1, 1) =(a∂x_{1}-b∂x_{2})(c∂x_{1}-d∂x_{2})<0$
#
# ### Therefore,
#
# $(a∂x_{1}-b∂x_{2})(c∂x_{1}-d∂x_{2})<0$
#
# ###So eithere $(a∂x_{1}-b∂x_{2}) or (c∂x_{1}-d∂x_{2}) should be negative, not both and a∂x_{1} ≠ b∂x_{2}, c∂x_{1} ≠ d∂x_{2}

# %% [markdown]
# ### Q2 (a). Find the point in the plane $x_{1} + 2x_{2} + 3x_{3} = 1$ in $R^3$ that is nearest to the point $(−1, 0, 1)^T$ . Is this a convex problem? Hint: Convert the problem into an unconstrained problem using $x_{1} + 2x_{2} + 3x_{3} = 1$
#
# ###Plane = $x_{1} + 2x_{2} + 3x_{3} = 1$
# ###Nearest to point $(−1, 0, 1)^T$
#
# ### To find the nearest point we should minimize the difference between the point we need to find $(x_{1},x_{2},x_{3})$ and point (-1, 0, 1)
#
# ###Therefore,
# $f = f(x_{1},x_{2},x_{3}) = min((x_{1}-(-1))^2+(x_{2}-0)^2+(x_{3}-1)^2)$
#
# ###Objective function, $f(x_{1},x_{2},x_{3}) = min((x_{1}-(-1))^2+x_{2}^2+(x_{3}-1)^2)$
#
# ###Constraints:
# ###Since the point should be in the plane $x_{1} + 2x_{2} + 3x_{3} = 1$, it must satisfy the equation of this plane. Therefore constraint is,
#
# $x_{1} + 2x_{2} + 3x_{3} = 1$
#
# ### To make the function unconstrained n, substistute $x_{1}=1-2x_{2}-3x_{3}$ in the objective function f:-
#
# $f(x_{1},x_{2},x_{3}) = (1-2x_{2}-3x_{3}+1)^2+x_{2}^2+(x_{3}-1)^2$
#
# $=(2-2x_{2}-3x_{3})(2-2x_{2}-3x_{3})+x_{2}^2+x_{3}^2+1-2x_{3}$
#
# $=4-4x_{2}-6x_{3}-4x_{2}+4x_{2}^2+6x_{2}x_{3}-6x_{3}+6x_{2}x_{3}+9x_{3}^2+x_{2}^2+x_{3}^2+1-2x_{3}$
#
# $=5x_{2}^2-8x_{2}+12x_{2}x_{3}+10x_{3}^2-14x_{3}+5$
#
# \begin{align}
# g(f) = \begin{bmatrix}
# ∂f/∂x_{2} \\
# ∂f/∂x_{3}
# \end{bmatrix}
# \end{align}
#
# \begin{align}
# g(f) = \begin{bmatrix}
# 10x_{2}-8+12x_{3} \\
# 12x_{2}+20x_{3}-14
# \end{bmatrix}
# \end{align}
#
# ###To find minimum, g(X)=0
#
# $10x_{2}-8+12x_{3} = 0$
#
# $12x_{2}+20x_{3}-14 = 0$
#
# ###By solving these equations, we get $x_{3}=11/14$, and $1x_{2}=-1/7$
#
# ###Substituting $x_{2}$ and $x_{3}$ values in constrain equation, $x_{1}=1-2x_{2}-3x_{3}$, we get $x_{1}= -15/14$
#
# ###Therefore, the nearest point $(x_{1}, x_{2},x_{3})= (-15/14, -1/7, 11/14)$
#
# \begin{align}
# H(f) = \begin{bmatrix}
# ∂^2f/∂x_{2}^2 & ∂^2f/∂x_{2}∂x_{3}\\
# ∂^2f/∂x_{3}∂x_{2} & ∂^2f/∂x_{3}^2
# \end{bmatrix} = \begin{bmatrix}
# 10 &12 \\
# 12 & 20
# \end{bmatrix}
# \end{align}
#
# ###Eigen values:
#
# AX = λX
#
# (A - λI)X = 0
#
# |A - λI|=0
#
# $λ_{1} = 28 ; λ_{2} = 2$
#
# ###Since all the eigen values are >0, the Hessian is positive definite. Since the Hessian is P.D. everywhere this function is convex function.

# %% [markdown]
# ###Q2.(b) mplement the gradient descent and Newton’s algorithm for solving the problem. Attach your codes in the report, along with a short summary of your findings. The summary should include: (1) The initial points tested; (2) corresponding solutions; (3) A log-linear convergence plot.

# %% [markdown]
# Gradient Method

# %%
import numpy as np
from numpy import linalg as LA
def func(x):
    f=5*x[0]**2-8*x[0]+12*x[0]*x[1]+10*x[1]**2-14*x[1]+5
    return f
def grad(x):
    g=np.array([10*x[0]-8+12*x[1],12*x[0]+20*x[1]-14])
    return g
def hess(x):
    h=np.array([[10,12],[12,20]])
    return h
def gradmet(x0):
        i=0
        c=0
        f=func(x0)
        g=grad(x0)
        h=hess(x0)
        gt=np.transpose(g)
        ng=LA.norm(g)
        while (ng>0.000001):
            f=func(x0)
            g=grad(x0)
            h=hess(x0)
            gt=np.transpose(g)
            ng=LA.norm(g)
            a=(np.dot(gt,g))/(np.dot((np.dot(gt,h)),g))
            x0=x0-a*g
            print("iteration{}=(x2,x3)={}".format(i,x0))
            if i==100:
                 break
            i=i+1

gradmet([1,-1])
# Out:
# iteration0=(x2,x3)=[ 1.36591479 -0.19498747]
# iteration1=(x2,x3)=[0.1233057  0.36983484]
# iteration2=(x2,x3)=[0.20852451 0.55731621]
# iteration3=(x2,x3)=[-0.08086982  0.68885909]
# iteration4=(x2,x3)=[-0.061023    0.73252209]
# iteration5=(x2,x3)=[-0.12842076  0.76315744]
# iteration6=(x2,x3)=[-0.12379858  0.77332622]
# iteration7=(x2,x3)=[-0.13949502  0.78046097]
# iteration8=(x2,x3)=[-0.13841855  0.7828292 ]
# iteration9=(x2,x3)=[-0.14207413  0.78449083]
# iteration10=(x2,x3)=[-0.14182343  0.78504237]
# iteration11=(x2,x3)=[-0.14267478  0.78542935]
# iteration12=(x2,x3)=[-0.1426164  0.7855578]
# iteration13=(x2,x3)=[-0.14281467  0.78564793]
# iteration14=(x2,x3)=[-0.14280108  0.78567784]
# iteration15=(x2,x3)=[-0.14284725  0.78569883]
# iteration16=(x2,x3)=[-0.14284409  0.7857058 ]
# iteration17=(x2,x3)=[-0.14285484  0.78571069]
# iteration18=(x2,x3)=[-0.1428541   0.78571231]
# iteration19=(x2,x3)=[-0.14285661  0.78571345]
# iteration20=(x2,x3)=[-0.14285643  0.78571383]
# ...

# %% [markdown]
# ##Result
#
# For initial point(1,1)
#
# $iteration0$, $(x_{2},x_{3})=$ [0.49751518, 0.35394809]
#
# $iteration1$, $(x_{2},x_{3})=$ [-0.07417103, 0.79859293]
#
# $iteration2$, $(x_{2},x_{3})=$ [-010437054, 0.75976499]
#
# $iteration3$, $(x_{2},x_{3})=$ [-0.13872908, 0.7864883]
#
# $iteration4$, $(x_{2},x_{3})=$ [-0.14054408, 0.788415472]
#
# $iteration5$, $(x_{2},x_{3})=$ [-0.14260905, 0.7857608]
#
# $iteration6$, $(x_{2},x_{3})=$ [-0.14271813, 0.78562056]
#
# $iteration7$, $(x_{2},x_{3})=$ [-0.14284223, 0.78571708]
#
# $iteration8$, $(x_{2},x_{3})=$ [-0.14284879, 0.78570865]
#
# $iteration9$, $(x_{2},x_{3})=$ [-0.14285625, 0.78571445]
#
# $iteration10$, $(x_{2},x_{3})=$ [-0.14285664, 0.78571395]
#
# $iteration11$, $(x_{2},x_{3})=$ [-0.14285709, 0.7857143]
#
# $iteration12$, $(x_{2},x_{3})=$ [-0.14285711, 0.78571427]
#
# $iteration13$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571429]

# %% [markdown]
# For initial point(100, 200)
#
# $iteration0$, $(x_{2},x_{3})=$ [-21.15151437, 14.77247833]
#
# $iteration1$, $(x_{2},x_{3})=$ [-0.04992271, 0.97058884]
#
# $iteration2$, $(x_{2},x_{3})=$ [-0.16235357, 0.79869426]
#
# $iteration3$, $(x_{2},x_{3})=$ [-0.1427709, 0.78588585]
#
# $iteration4$, $(x_{2},x_{3})=$ [-0.14287524, 0.78572633]
#
# $iteration5$, $(x_{2},x_{3})=$ [-0.14285706, 0.78571444]
#
# $iteration6$, $(x_{2},x_{3})=$ [-0.14285716, 0.7857143]
#
# $iteration7$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571429]

# %% [markdown]
# For initial point(3000,2700)
#
# $iteration0$, $(x_{2},x_{3})=$ [93685.80183447, 133493.25176107]
#
# $iteration1$, $(x_{2},x_{3})=$ [3015.23281209, 2009.99676567]
#
# $iteration2$, $(x_{2},x_{3})=$ [3.16384063, 5.49740547]
#
# $iteration3$, $(x_{2},x_{3})=$ [-0.03642777, 0.71474259]
#
# $iteration4$, $(x_{2},x_{3})=$ [-0.14285339, 0.78588059]
#
# $iteration5$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571178]
#
# $iteration6$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571429]
#
# $iteration7$, $(x_{2},x_{3})=$ [-0.14285714, 0.7871429]

# %% [markdown]
# ###The log-linear convergence plot
# ![2b.png](data:image/png;base64,...)

# %% [markdown]
# Newton's Method

# %%
import numpy as np
from numpy import linalg as LA
def func(x):
    f=5*x[0]**2-8*x[0]+12*x[0]*x[1]+10*x[1]**2-14*x[1]+5
    return f
def grad(x):
    g=np.array([10*x[0]-8+12*x[1],12*x[0]+20*x[1]-14])
    return g
def hess(x):
    h=np.array([[10,12],[12,20]])
    return h
def newmet(x0):
        i=0
        c=0
        f=func(x0)
        g=grad(x0)
        h=hess(x0)
        gt=np.transpose(g)
        ng=LA.norm(g)
        while (ng>0.000001):
            f=func(x0)
            g=grad(x0)
            h=hess(x0)
            hi=np.linalg.inv(h)
            gt=np.transpose(g)
            ng=LA.norm(g)
            a=1

            x0=x0-a*(np.dot(hi,g))
            print("iteration{}=(x2,x3)={}".format(i,x0))
            a=(np.dot(gt,g))/(np.dot((np.dot(gt,h)),g))
            if i==100:
                 break
            i=i+1

newmet([1,-1])
# Out:
# iteration0=(x2,x3)=[-0.14285714  0.78571429]
# iteration1=(x2,x3)=[-0.14285714  0.78571429]

# %% [markdown]
# ##Result
#
# For initial point(1,1)
#
# $iteration0$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571429]
#
# $iteration1$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571429]
#
#
#
# For initial point(100,200)
#
# $iteration0$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571429]
#
# $iteration1$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571429]
#
#
#
#
# For initial point(3000,2700)
#
# $iteration0$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571429]
#
# $iteration1$, $(x_{2},x_{3})=$ [-0.14285714, 0.78571429]
#
#
#
# ###Inference
#
# We can see that the gradient method takes multiple steps depending on step size to achieve the optimal solution, but the Newton's method directly gives the solution in a single step. This is because the function is quadratic so the second order taylor approximation will provide the optimal solution.

# %% [markdown]
# ### Q3. Prove that a hyperplane is a convex set. Hint: A hyperplane in $R^n$ can be expressed as: $a^T x = c$ for $x ∈ R^n$, where 'a' is the normal direction of the hyperplane and c is some constant.
#
# ###Answer:
#
# Considering Hyperplane,
#
# $f =$ {$x | where, x ∈ R^n, a^Tx=c$}
#
# Let $x_{1}$ and $x_{2}$ be any two points in hyperplane f,
#
# Therefore, $x_{1}∈R$, $x_{2}∈R$
#
# $a^Tx_{1}=c, a^Tx_{2}=c$
#
# ∀λ ∈ [0,1], ∀($x_{1},x_{2}$) ∈ x
#
# z = λ$x_{1}$ + (1 - λ)$x_{2}$
#
# To check, $a^Tx_{1}=c$
#
# $a^Tz=a^T$(λ$x_{1}$ + (1 - λ)$x_{2}$) = $λa^Tx_{1}+(1-λ)a^Tx_{2}=c$
#
# Therefore $z = λx_{1}+(1-λx_{2})∈$ hyperplane f
#
# Hence, its proved that hyperplane is a convex set

# %% [markdown]
# ###Q4. Consider the following illumination problem:
# min(p)  max (k) {h($a^T_{k}p, I_{t}$)}
#
# subject to: 0 ≤ pi ≤ $p_{max}$,
#
#
# where p := $[p1, ..., pn]^T$ are the power output of the n lamps, $a_{k}$ for
# k = 1, ..., , m are fixed parameters for the m mirrors, $I_{t}$ the target
# intensity level. h($I$, $I_{t}$) is defined as follows:
#
# h($I, I_{t}$) ={ $I_{t}/I if I ≤ I_{t}$;
#
# $I/I_{t} if I_{t} ≤ I$
#
#
# ###(a) Show that the problem is convex
#
# ###Answer:
#
# H($I,I_{T}$)={$I_{T}/I$ if $I ≤ I_{t}, I/I_{t}$ if $I_{t} ≤ I$}
#
# let $H_{1}$ = $I_{T}/I$ if $I ≤ I_{t}$
#
# let $H_{2}$ = $I/I_{t}$ if $I_{t} ≤ I$
#
# ![4a.PNG](data:image/png;base64,...)
#
#
# ### We can observe that the function $H_{1}$ is monotonically decreasing while the function $H_{2}$ is linear. Therefore the solution should be the intersection of the two functions $H_{1}$ and $H_{2}$. The solution cannot be elsewhere because it will slip down to the lowest value. At the intersection point, all the functions of $H_{1}$ will be equal and similarly all the functions of $H_{2}$ will be equal
#
# ###Therefore,
#
# $a^T_{1}p/I_{t} = a^T_{2}p/I_{t} = ..... = a^T_{n}p/I_{t}$
#
# $I_{t}/((a^*_{1})^Tp) = I_{t}/((a^*_{2})^Tp) = ..... = I_{t}/((a^*_{n})^Tp)$
#
# ###Therefore
#
# $a^T_{1}p/I_{t} - a^T_{2}p/I_{t} = 0$
#
# $a^T_{1}p-a^T_{2}p/I_{t} = 0$
#
# $(a_{1}-a_{2})^Tp = 0$
#
# Similarly, $(a_{2}-a_{3})^Tp = 0$, $(a_{3}-a_{4})^Tp = 0$.......
#
# These constraints are in form $A^Tp=0$
#
# Therefore, these constraints are linear and our optimization function is,
#
# $f = min(p)=I_{t}/a_{T}p$
#
# st: $A^Tp = 0$
#
#
# ∂f/∂p = $-I_{t}/a_{T}p^2$
#
# ∂^2f/∂p^2 = $2I_{t}/a_{T}p^3$
#
# ###Since p is the power output of n lamps which is positive, the hessian is positive. Since the hessian is positive this function is strictly convex with respect to p. Since we are taking the max of all convex functions, this problem will also be convex.
#
# ###(b) we require the overall power output of any of the 10 lamps to be less than p∗, will the problem have a unique solution?
#
# ###Answer:Taking any ten lamps from n lamps:
#
# $$
# C^{10}_{n} = \left\{
#     \begin{array}\\
#     p_{1}+p_{2}+....+p_{10}<=p^*\\
#     p_{2}+p_{3}+....+p_{11}<=p^*\\
#     . \\
#     . \\
#     . \\
#     . \\
#     . \\
#     . \\
#     p_{n-9}+p_{n-8}+....+p_{n}<=p^*
#     \end{array}
# \right\}
# $$
#
# ### All these constraints are linear with respect to p
# ###Since the original function is strictly convex and the feasible set is convex, the problem has a unique solution.
#
# ###(c) If we require no more than 10 lamps to be switched on (p > 0), will the problem have a unique solution?
#
# ###Answer:This problem has n lamps which we assume it is more than 10. So if no more than 10 lamps are on, that means the n-10 lamps are off. If we take two points, one from the function of the lamp that is on and another from the lamp that is off and draw a line between them, we can find that the feasible set is not convex. Adding this constrain made the problem non-convex, thus we cannot tell how many local solutions we have.

# %% [markdown]
# ###Q5. Let c(x) be the cost of producing x amount of product A and assume that c(x) is differentiable everywhere. Let y be the price set for the product. Assuming that the product is sold out. The total profit is defined as
#
#
# $c^*(y) = max (x)$ {xy-c(x)}
#
# Show that $c^∗(y)$ is a convex function with respect to y.
#
#
# ###Answer:
#
# Profit, $c^*(y) = max (x)$ {xy-c(x)}
#
# $c^*(y) = max (x) \left\{
#     \begin{array}\\
#     x_{1}y-c(x_{1})\\
#     x_{2}y-c(x_{2})\\
#     . \\
#     . \\
#     . \\
#     . \\
#     . \\
#     . \\
#     x_{n}y-c(x_{n})
#     \end{array}
# \right\}
# $
#
# Let $f_{1}=x_{1}y-c(x_{1})$
#
# $∂f_{1}/∂y = x_{1}$
#
# $∂^2f_{1}/∂y^2 = 0$
#
# ###The function $f_{1}$ is a linear function with respect to y. Similarly all the functions $(xy-c(x))$ are linear with respect to y.
#
# ###Therefore, all these fuunctions are convex with respect to y. Since $C^*(y)$ is the maximum of all the functions which are convex with respect to y,$C^*(y)$ is alsoconvex with respect to y.
